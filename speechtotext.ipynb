# %% [markdown]
# <a href="https://colab.research.google.com/github/kanchan9675/AdvAITrainingSecD/blob/main/speechtotext.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#create audio to text using whisper model and upload the code to github repo
